# %% [markdown]
# # Install the latest version of pami

# %%
# !pip install pami==2024.5.1.1
# Out:
# Collecting pami==2024.5.1.1
#   Downloading pami-2024.5.1.1-py3-none-any.whl (991 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 991.0/991.0 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (5.9.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (2.0.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (5.15.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (3.7.1)
# Requirement already satisfied: resource in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (0.2.1)
# Requirement already satisfied: validators in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (0.28.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (2.0.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (1.25.2)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (5.0.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (2.0.0)
# Requirement already satisfied: discord.py in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (2.3.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (3.3)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.10/dist-packages (from pami==2024.5.1.1) (1.2.14)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->pami==2024.5.1.1) (1.14.1)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from discord.py->pami==2024.5.1.1) (3.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pami==2024.5.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pami==2024.5.1.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pami==2024.5.1.1) (2024.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->pami==2024.5.1.1) (8.2.3)
# Requirement already satisfied: JsonForm>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from resource->pami==2024.5.1.1) (0.0.2)
# Requirement already satisfied: JsonSir>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from resource->pami==2024.5.1.1) (0.0.2)
# Requirement already satisfied: python-easyconfig>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from resource->pami==2024.5.1.1) (0.1.7)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (1.0.7)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (3.1.3)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (2.16.1)
# Requirement already satisfied: docutils<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (0.18.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (2.14.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (0.7.16)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx->pami==2024.5.1.1) (2.31.0)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->pami==2024.5.1.1) (4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.7.4->discord.py->pami==2024.5.1.1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.7.4->discord.py->pami==2024.5.1.1) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.7.4->discord.py->pami==2024.5.1.1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.7.4->discord.py->pami==2024.5.1.1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.7.4->discord.py->pami==2024.5.1.1) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.7.4->discord.py->pami==2024.5.1.1) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx->pami==2024.5.1.1) (2.1.5)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from JsonForm>=0.0.2->resource->pami==2024.5.1.1) (4.19.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->pami==2024.5.1.1) (1.16.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from python-easyconfig>=0.1.0->resource->pami==2024.5.1.1) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->pami==2024.5.1.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->pami==2024.5.1.1) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx->pami==2024.5.1.1) (2024.2.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->pami==2024.5.1.1) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->pami==2024.5.1.1) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->pami==2024.5.1.1) (0.18.0)
# Installing collected packages: pami
#   Attempting uninstall: pami
#     Found existing installation: pami 2024.5.1
#     Uninstalling pami-2024.5.1:
#       Successfully uninstalled pami-2024.5.1
# Successfully installed pami-2024.5.1.1

# %% [markdown]
# # Download the transactional Database

# %%
# !wget -nc https://u-aizu.ac.jp/~udayrage/datasets/transactionalDatabases/Transactional_T10I4D100K.csv
# Out:
# --2024-05-03 04:29:06--  https://u-aizu.ac.jp/~udayrage/datasets/transactionalDatabases/Transactional_T10I4D100K.csv
# Resolving u-aizu.ac.jp (u-aizu.ac.jp)... 150.95.161.176, 150.31.244.160
# Connecting to u-aizu.ac.jp (u-aizu.ac.jp)|150.95.161.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4019277 (3.8M) [text/csv]
# Saving to: ‘Transactional_T10I4D100K.csv’
#
# Transactional_T10I4 100%[===================>]   3.83M  1.01MB/s    in 5.6s
#
# 2024-05-03 04:29:13 (705 KB/s) - ‘Transactional_T10I4D100K.csv’ saved [4019277/4019277]

# %% [markdown]
# # Intialize the input parameters

# %%
inputFile = "Transactional_T10I4D100K.csv"
sep = "\t"
minSup = 0.005

# %% [markdown]
# # Step 1. Minig the frequent pattern mining algorithm

# %% [markdown]
# ## Get the frequent patterns using FPGrowth algorithm (algorithm is user choice)

# %%
from PAMI.frequentPattern.basic.FPGrowth import FPGrowth

obj = FPGrowth(inputFile, minSup, sep)
obj.mine()
obj.printResults()
obj.save("frequentPatterns.csv")
frequentPatternsDataFrame = obj.getPatternsAsDataFrame()
# Out:
# Frequent patterns were generated successfully using frequentPatternGrowth algorithm
# Total number of Frequent Patterns: 1072
# Total Memory in USS: 505810944
# Total Memory in RSS 527843328
# Total ExecutionTime in ms: 12.618626832962036

# %% [markdown]
# # Store the frequent patterns either in dataframe or csv file

# %% [markdown]
# ### Print the frequent patterns stored in dataFrame

# %%
frequentPatternsDataFrame
# Out:
#         Patterns  Support
# 0         (657,)      505
# 1         (771,)      505
# 2         (144,)      505
# 3         (934,)      510
# 4         (868,)      510
# ...          ...      ...
# 1067  (829, 529)      584
# 1068  (829, 368)     1192
# 1069      (529,)     7053
# 1070  (529, 368)      639
# 1071      (368,)     7821
#
# [1072 rows x 2 columns]

# %% [markdown]
# # step. 2: Extraction of Association Rules providing frequentPatternsDataFrame as inputFile

# %% [markdown]
# ## intialize the input parameters.

# %%
minConf = 0.5
minLift = 0.01
maxTS = 99935

# %% [markdown]
# ## Extract the Association Rules using confidence as threshold

# %%
from PAMI.AssociationRules.basic import confidence as alg
obj = alg.confidence(frequentPatternsDataFrame, minConf, sep)
obj.mine()
obj.printResults()
obj.save("associationRulesconfidence.csv")
obj.getAssociationRulesAsDataFrame()
# Out:
# Association rules successfully  generated from frequent patterns
# Total number of Association Rules: 2215
# Total Memory in USS: 465125376
# Total Memory in RSS 486772736
# Total ExecutionTime in ms: 0.005249738693237305
#                            Patterns     Support
# 0                            (657,)  505.000000
# 1                            (771,)  505.000000
# 2                            (144,)  505.000000
# 3                            (934,)  510.000000
# 4                            (868,)  510.000000
# ...                             ...         ...
# 2210  (217, 283, ->, 217, 283, 346)    0.892857
# 2211  (217, 346, ->, 217, 283, 346)    0.618441
# 2212  (283, 346, ->, 217, 283, 346)    0.908590
# 2213  (368, 494, ->, 368, 494, 682)    0.686845
# 2214  (494, 682, ->, 368, 494, 682)    0.827489
#
# [2215 rows x 2 columns]

# %% [markdown]
# ## Extract the Association Rules using lift as threshold

# %%
from PAMI.AssociationRules.basic import lift as alg
obj = alg.lift(frequentPatternsDataFrame, minLift, sep)
obj.mine()
obj.printResults()
obj.save("associationRuleslift.csv")
obj.getPatternsAsDataFrame()
# Out:
# Association rules successfully  generated from frequent patterns
# Total number of Association Rules: 3282
# Total Memory in USS: 465362944
# Total Memory in RSS 487329792
# Total ExecutionTime in ms: 0.009712457656860352
#                  Patterns      Support
# 0                  (657,)   505.000000
# 1                  (771,)   505.000000
# 2                  (144,)   505.000000
# 3                  (934,)   510.000000
# 4                  (868,)   510.000000
# ...                   ...          ...
# 3277  (829, ->, 529, 829)   605.550132
# 3278  (368, ->, 368, 829)  1036.694029
# 3279  (829, ->, 368, 829)  1370.572185
# 3280  (368, ->, 368, 529)   576.252014
# 3281  (529, ->, 368, 529)   708.580604
#
# [3282 rows x 2 columns]

# %% [markdown]
# ## Extract the Association Rules using leverage as threshold

# %%
from PAMI.AssociationRules.basic import leverage as alg
obj = alg.leverage(frequentPatternsDataFrame, minLift, sep, maxTS)
obj.mine()
obj.printResults()
obj.save("associationRulesleverage.csv")
obj.getAssociationRulesAsDataFrame()
# Out:
# Association rules successfully  generated from frequent patterns
# Total number of Association Rules: 1084
# Total Memory in USS: 465375232
# Total Memory in RSS 487329792
# Total ExecutionTime in ms: 0.009909629821777344
#                  Patterns   Support
# 0                  (657,)  0.005053
# 1                  (771,)  0.005053
# 2                  (144,)  0.005053
# 3                  (934,)  0.005103
# 4                  (868,)  0.005103
# ...                   ...       ...
# 1079   (704, ->, 39, 704)  0.010303
# 1080    (39, ->, 39, 825)  0.010554
# 1081   (825, ->, 39, 825)  0.010554
# 1082  (217, ->, 217, 346)  0.011484
# 1083  (346, ->, 217, 346)  0.011484
#
# [1084 rows x 2 columns]
